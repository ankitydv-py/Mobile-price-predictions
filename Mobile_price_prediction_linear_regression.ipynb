# %% [markdown]
# # Linear regression

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("mobile_train.csv")

# %%
dataset.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
dataset.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#our target is prediction of price range

# %%
target = dataset.price_range

# %%
#stat of the dataset

# %%
dataset.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
#importing libraries for data visualisation and analysis

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sb

# %%
# %matplotlib inline

# %%
#how ram affected by price

# %%
#train_dataset = dataset.drop('price_range',axis = 1)

# %%
train_dataset_x = dataset.drop(['price_range','blue','mobile_wt','talk_time','wifi'],axis = 'columns')

# %%
#split dataset into train and testing datasets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train_dataset_x, target, test_size=0.33, random_state=101)

# %%
#model training

# %%
from sklearn.linear_model import LinearRegression
pred_model = LinearRegression()

# %%
pred_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred_model.score(X_test,Y_test)
# Out:
# 0.9124894707357876

# %%
test_dataset = pd.read_csv("mobile_test.csv")

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
predict_data = test_dataset.drop(['id','blue','mobile_wt','talk_time','wifi'],axis = 'columns')

# %%
predict_data.head()
# Out:
#    battery_power  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043          1.8         1  14       0           5    0.1
# 1            841          0.5         1   4       1          61    0.8
# 2           1807          2.8         0   1       0          27    0.9
# 3           1546          0.5         1  18       1          25    0.5
# 4           1434          1.4         0  11       1          49    0.5
#
#    n_cores  pc  px_height  px_width   ram  sc_h  sc_w  three_g  touch_screen
# 0        3  16        226      1412  3476    12     7        0             1
# 1        5  12        746       857  3895     6     0        1             0
# 2        3   4       1270      1366  2396    17    10        0             1
# 3        8  20        295      1752  3893    10     0        1             1
# 4        6  18        749       810  1773    15     8        1             0

# %%
train_dataset_x.head()
# Out:
#    battery_power  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842          2.2         0   1       0           7    0.6
# 1           1021          0.5         1   0       1          53    0.7
# 2            563          0.5         1   2       1          41    0.9
# 3            615          2.5         0   0       0          10    0.8
# 4           1821          1.2         0  13       1          44    0.6
#
#    n_cores  pc  px_height  px_width   ram  sc_h  sc_w  three_g  touch_screen
# 0        2   2         20       756  2549     9     7        0             0
# 1        3   6        905      1988  2631    17     3        1             1
# 2        5   6       1263      1716  2603    11     2        1             1
# 3        6   9       1216      1786  2769    16     8        1             0
# 4        2  14       1208      1212  1411     8     2        1             1

# %%
predicted_price = pred_model.predict(predict_data)

# %%
predicted_price
# Out:
# array([ 2.56837364e+00,  2.92080256e+00,  2.27636483e+00,  3.39832945e+00,
#         1.20627719e+00,  2.84022365e+00,  3.65154834e+00,  1.06208799e+00,
#         2.58495262e+00, -5.27960060e-02,  3.30474413e+00,  3.27374524e+00,
#        -8.54846012e-02,  4.14364829e-01,  2.07949126e+00,  3.76180038e-01,
#         1.93289737e+00,  1.15385031e+00,  3.15536356e+00,  1.61864510e+00,
#         7.85974178e-01,  2.46792197e+00,  1.33206468e+00,  1.31042933e+00,
#         3.20609567e+00,  2.91135644e-02,  2.03569447e+00, -4.12166404e-01,
#         2.61120715e+00, -3.61855971e-02,  2.17090387e+00,  2.30334124e-01,
#         2.83302009e+00,  1.91364276e-01,  5.72364060e-01,  9.58373013e-01,
#         2.75103876e+00,  1.14821145e+00,  2.13601110e+00,  9.14894027e-01,
#         1.20067193e+00,  1.74965537e+00, -4.60356268e-01, -3.72084859e-01,
#        -5.62429356e-03,  7.99233847e-01,  4.14762100e-01,  2.61296391e+00,
# ...

# %%
predict_data['price_range']=predicted_price

# %%
predict_data.head()
# Out:
#    battery_power  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043          1.8         1  14       0           5    0.1
# 1            841          0.5         1   4       1          61    0.8
# 2           1807          2.8         0   1       0          27    0.9
# 3           1546          0.5         1  18       1          25    0.5
# 4           1434          1.4         0  11       1          49    0.5
#
#    n_cores  pc  px_height  px_width   ram  sc_h  sc_w  three_g  touch_screen  \
# 0        3  16        226      1412  3476    12     7        0             1
# 1        5  12        746       857  3895     6     0        1             0
# 2        3   4       1270      1366  2396    17    10        0             1
# 3        8  20        295      1752  3893    10     0        1             1
# 4        6  18        749       810  1773    15     8        1             0
#
#    price_range
# 0     2.568374
# 1     2.920803
# 2     2.276365
# ...

# %%
# converting 'price' from float to int 
predict_data['price_range'] = predict_data['price_range'].astype(int)

# %%
predict_data.head(10)
# Out:
#    battery_power  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043          1.8         1  14       0           5    0.1
# 1            841          0.5         1   4       1          61    0.8
# 2           1807          2.8         0   1       0          27    0.9
# 3           1546          0.5         1  18       1          25    0.5
# 4           1434          1.4         0  11       1          49    0.5
# 5           1464          2.9         1   5       1          50    0.8
# 6           1718          2.4         0   1       0          47    1.0
# 7            833          2.4         1   0       0          62    0.8
# 8           1111          2.9         1   9       1          25    0.6
# 9           1520          0.5         0   1       0          25    0.5
#
#    n_cores  pc  px_height  px_width   ram  sc_h  sc_w  three_g  touch_screen  \
# 0        3  16        226      1412  3476    12     7        0             1
# ...
