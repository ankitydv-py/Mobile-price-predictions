# %% [markdown]
# # KNN Classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
training_dataset = pd.read_csv("mobile_train.csv")

# %%
training_dataset.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
training_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#check for the null values in the dataset
training_dataset.isnull().values.any()
# Out:
# False

# %%
#set the price_range as the target value

target_value = training_dataset.price_range

# %%
training_dataset.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
#drop the attributes bluetooth, mobile weight, talktime, wifi and prince range(target) 

training_dataset_x = training_dataset.drop(['price_range','blue','mobile_wt','talk_time','wifi'],axis = 'columns')

# %%
training_dataset_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   clock_speed    2000 non-null   float64
#  2   dual_sim       2000 non-null   int64
#  3   fc             2000 non-null   int64
#  4   four_g         2000 non-null   int64
#  5   int_memory     2000 non-null   int64
#  6   m_dep          2000 non-null   float64
#  7   n_cores        2000 non-null   int64
#  8   pc             2000 non-null   int64
#  9   px_height      2000 non-null   int64
#  10  px_width       2000 non-null   int64
#  11  ram            2000 non-null   int64
#  12  sc_h           2000 non-null   int64
#  13  sc_w           2000 non-null   int64
#  14  three_g        2000 non-null   int64
#  15  touch_screen   2000 non-null   int64
# dtypes: float64(2), int64(14)
# memory usage: 250.1 KB

# %%
#split dataset into train and testing datasets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(training_dataset_x, target_value, test_size=0.33, random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=10)
knn_model.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn_model.score(X_test,Y_test)
# Out:
# 0.9212121212121213

# %%
#now prediction of the test dataset

# %%
testing_dataset = pd.read_csv("mobile_test.csv")

# %%
testing_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
#drop the attributes id,bluetooth, mobile weight, talktime, wifi

# %%
testing_dataset_x = testing_dataset.drop(['id','blue','mobile_wt','talk_time','wifi'],axis = 'columns')

# %%
knn_model.predict(testing_dataset_x)
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 1, 1, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 0, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 0, 3, 1, 1, 3, 3, 2, 0, 1, 0, 1,
#        1, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 1, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 1, 2, 1, 0, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 3, 1, 0, 2,
#        1, 1, 3, 1, 1, 0, 3, 2, 1, 3, 1, 3, 2, 3, 3, 3, 2, 3, 2, 3, 0, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 1, 1, 0, 1,
#        0, 0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        3, 3, 1, 1, 3, 3, 3, 2, 2, 1, 1, 0, 1, 2, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 2, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 2, 0, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 2, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 1, 2, 3, 1, 1, 3, 2, 0, 3, 0, 0, 3, 0, 0, 3, 2, 3,
# ...

# %%
test_prediction = knn_model.predict(testing_dataset_x)

# %%
testing_dataset_x['price_range']=test_prediction

# %%
testing_dataset_x.head(10)
# Out:
#    battery_power  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043          1.8         1  14       0           5    0.1
# 1            841          0.5         1   4       1          61    0.8
# 2           1807          2.8         0   1       0          27    0.9
# 3           1546          0.5         1  18       1          25    0.5
# 4           1434          1.4         0  11       1          49    0.5
# 5           1464          2.9         1   5       1          50    0.8
# 6           1718          2.4         0   1       0          47    1.0
# 7            833          2.4         1   0       0          62    0.8
# 8           1111          2.9         1   9       1          25    0.6
# 9           1520          0.5         0   1       0          25    0.5
#
#    n_cores  pc  px_height  px_width   ram  sc_h  sc_w  three_g  touch_screen  \
# 0        3  16        226      1412  3476    12     7        0             1
# ...
